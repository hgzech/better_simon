# %% [markdown]
# # Fast
#
# > Some initial design ideas

# %%
#| default_exp playground

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import pandas as pd
import itertools

# %%
# Defining the two sets
Ss = ['L1','L2','R1','R2']
Rs = ['L', 'R']

# Generating all combinations by crossing the two sets
combinations_crossed = list(itertools.product(Ss, Rs, repeat=2))

# Convert to DataFrame
df_crossed = pd.DataFrame(combinations_crossed, columns=['S1', 'R1', 'S2', 'R2'])
df_crossed
# Out:
#     S1 R1  S2 R2
# 0    L  L   L  L
# 1    L  L   L  R
# 2    L  L   R  L
# 3    L  L   R  R
# 4    L  L  L2  L
# ..  .. ..  .. ..
# 59  R2  R   R  R
# 60  R2  R  L2  L
# 61  R2  R  L2  R
# 62  R2  R  R2  L
# 63  R2  R  R2  R
#
# [64 rows x 4 columns]

# %%
def check_feature_match(row):
    # Creating lists from the first two and the last two columns
    list1 = [row['S1'], row['R1']]
    list2 = [row['S2'], row['R2']]

    # Comparing the lists
    if list1 == list2:
        return "complete_match"
    elif all(item1 != item2 for item1, item2 in zip(list1, list2)):
        return "complete_mismatch"
    else:
        return "partial_match"

# %%
def get_possible_trial_sequences(Ss, Rs):
    #Ss = ['L', 'R']
    #Rs = ['L', 'R']
    
    # Generating all combinations by crossing the two sets
    combinations_crossed = list(itertools.product(Ss, Rs, repeat=2))
    
    # Convert to DataFrame
    df_permutations = pd.DataFrame(combinations_crossed, columns=['S1', 'R1', 'S2', 'R2'])
    
    # Convert to DataFrame
    #df_permutations = pd.DataFrame(permutations, columns=['S1', 'R1', 'S2', 'R2'])
    # Adding columns to check if S1 equals R1 and if S2 equals R2
    df_permutations['S1_R1_corresp'] = df_permutations['S1'].str[0] == df_permutations['R1'].str[0]
    df_permutations['S2_R2_corresp'] = df_permutations['S2'].str[0] == df_permutations['R2'].str[0]
    df_permutations['S_loc_rep'] = df_permutations['R1'].str[0] == df_permutations['R2'].str[0]
    df_permutations['S_R_loc_rep'] = df_permutations['S1'].str[0] == df_permutations['S2'].str[0]
    df_permutations['feature_match'] = df_permutations.apply(check_feature_match, axis=1)
    df_permutations['complete_match_mismatch'] = df_permutations.feature_match.isin(["complete_match", "complete_mismatch"])
    df_permutations['cC_iI'] = df_permutations['S1_R1_corresp'] == df_permutations['S2_R2_corresp']
    df_permutations = df_permutations.drop(columns = ['feature_match'])
    return df_permutations

Ss = ['L','R']
Rs = ['L', 'R']
possible_sequences = get_possible_trial_sequences(Ss, Rs)
possible_sequences
# Out:
#    S1 R1 S2 R2  S1_R1_corresp  S2_R2_corresp  S_loc_rep  S_R_loc_rep  \
# 0   L  L  L  L           True           True       True         True
# 1   L  L  L  R           True          False      False         True
# 2   L  L  R  L           True          False       True        False
# 3   L  L  R  R           True           True      False        False
# 4   L  R  L  L          False           True      False         True
# 5   L  R  L  R          False          False       True         True
# 6   L  R  R  L          False          False      False        False
# 7   L  R  R  R          False           True       True        False
# 8   R  L  L  L          False           True       True        False
# 9   R  L  L  R          False          False      False        False
# 10  R  L  R  L          False          False       True         True
# 11  R  L  R  R          False           True      False         True
# 12  R  R  L  L           True           True      False        False
# 13  R  R  L  R           True          False       True        False
# 14  R  R  R  L           True          False      False         True
# 15  R  R  R  R           True           True       True         True
#
#     complete_match_mismatch  cC_iI
# 0                      True   True
# 1                     False  False
# 2                     False  False
# 3                      True   True
# 4                     False  False
# 5                      True   True
# 6                      True   True
# 7                     False  False
# 8                     False  False
# 9                      True   True
# 10                     True   True
# 11                    False  False
# 12                     True   True
# 13                    False  False
# 14                    False  False
# 15                     True   True

# %% [markdown]
# ## Todo

# %%
# %%time

def generate_block(N, possible_sequences):
    current = possible_sequences.sample(1)
    trials = []
    trials.append(current)
    for i in range(N-1):
        current = possible_sequences.query(f"(S1=='{current['S2'].values[0]}') and (R1=='{current['R2'].values[0]}')").sample(1)
        trials.append(current)
    trials = pd.concat(trials, ignore_index = True)
    columns_to_shift = ['S_R_loc_rep', 'S_loc_rep','complete_match_mismatch', 'cC_iI']
    trials[columns_to_shift] = trials[columns_to_shift].shift(1)
    trials = trials.fillna(False)
    trials = trials.drop(columns = ['S2','R2','S2_R2_corresp'])
    return trials

def check_balance(trials):
    # Discard the first trial during check
    trials_check = trials.iloc[1:]
    percent_cC_iI = trials_check.cC_iI.mean()
    agg = trials_check.set_index(['S1','R1']).groupby('cC_iI').mean()
    imbalance = agg.loc[False] - agg.loc[True]
    imbalance['percent_cC_iI'] = percent_cC_iI
    
    return imbalance
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs

# %% [markdown]
# ## Todo
# perhaps I can increase efficiency by just always sampling 50 percent cc_ii trials

# %%
# %%time
from joblib import Parallel, delayed

def process_iteration(i):
    trials = generate_block(N, possible_sequences) # This might be a stupid way of doing that. I could just create at random and make new functions for creating variables
    imbalance = check_balance(trials)
    return trials, imbalance

# Assuming 'N' and 'possible_sequences' are defined earlier in your code
Ss = ['L1','L2','R1','R2']
Rs = ['L', 'R']
possible_sequences = get_possible_trial_sequences(Ss, Rs)
N = 33

# Parallel execution
results = Parallel(n_jobs=-1)(delayed(process_iteration)(i) for i in range(500000))

# Unpacking results
blocks, imbalances = zip(*results)
df = pd.DataFrame(imbalances)

# %% [markdown]
# In a six stimuli, simon task, there are certain sequences that balance feature repetition and feature unbinding effects between the different conditions required to calculate conflict adaptation.

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05)").query("(percent_cC_iI>.45) and (percent_cC_iI<.55)").query("(S_R_loc_rep>-.05) and (S_R_loc_rep<.05)").query("(S_loc_rep>-.05) and (S_loc_rep<.05)")
# Out:
#          S1_R1_corresp  S_loc_rep  S_R_loc_rep  complete_match_mismatch  \
# 15504          -0.2500        0.0          0.0                      0.0
# 136038         -0.3750        0.0          0.0                      0.0
# 234011          0.1250        0.0          0.0                      0.0
# 284796          0.2500        0.0          0.0                      0.0
# 310421          0.2500        0.0          0.0                      0.0
# 374139          0.1875        0.0          0.0                      0.0
# 428728          0.1250        0.0          0.0                      0.0
# 447811         -0.3125        0.0          0.0                      0.0
# 467145         -0.2500        0.0          0.0                      0.0
# 550577         -0.0625        0.0          0.0                      0.0
# 758936         -0.1875        0.0          0.0                      0.0
# 874667         -0.1875        0.0          0.0                      0.0
# 996490         -0.3125        0.0          0.0                      0.0
# 1002797        -0.0625        0.0          0.0                      0.0
# 1015184        -0.0625        0.0          0.0                      0.0
# 1080684         0.0625        0.0          0.0                      0.0
# 1141578         0.1250        0.0          0.0                      0.0
# 1299666        -0.1250        0.0          0.0                      0.0
# 1545677        -0.1875        0.0          0.0                      0.0
# 1572574        -0.1250        0.0          0.0                      0.0
# 1635686         0.0625        0.0          0.0                      0.0
# 1664654        -0.2500        0.0          0.0                      0.0
# 1916676        -0.0625        0.0          0.0                      0.0
# 1923687         0.3125        0.0          0.0                      0.0
#
#          percent_cC_iI
# 15504              0.5
# 136038             0.5
# 234011             0.5
# 284796             0.5
# 310421             0.5
# 374139             0.5
# 428728             0.5
# 447811             0.5
# 467145             0.5
# 550577             0.5
# 758936             0.5
# 874667             0.5
# 996490             0.5
# 1002797            0.5
# 1015184            0.5
# 1080684            0.5
# 1141578            0.5
# 1299666            0.5
# 1545677            0.5
# 1572574            0.5
# 1635686            0.5
# 1664654            0.5
# 1916676            0.5
# 1923687            0.5

# %%
blocks[422685]
# Out:
#     S1 R1  S1_R1_corresp  S_loc_rep  S_R_loc_rep  complete_match_mismatch  \
# 0   L1  R          False      False        False                    False
# 1   L2  L           True      False         True                     True
# 2   R2  L          False       True        False                    False
# 3   L1  L           True       True        False                    False
# 4   L2  L           True       True         True                    False
# 5   L1  L           True       True         True                    False
# 6   L1  L           True       True         True                     True
# 7   R2  L          False       True        False                    False
# 8   L1  R          False      False        False                     True
# 9   L2  L           True      False         True                     True
# 10  R2  R           True      False        False                     True
# 11  R1  L          False      False         True                     True
# 12  R2  R           True      False         True                     True
# 13  R1  R           True       True         True                    False
# 14  R2  L          False      False         True                     True
# 15  L2  R          False      False        False                     True
# 16  L1  R          False       True         True                    False
# 17  L2  L           True      False         True                     True
# 18  R2  L          False       True        False                    False
# 19  L1  R          False      False        False                     True
# 20  R1  L          False      False        False                     True
# 21  L2  R          False      False        False                     True
# 22  L1  R          False       True         True                    False
# 23  L2  R          False       True         True                    False
# 24  R1  R           True       True        False                    False
# 25  L1  L           True      False        False                     True
# 26  L2  L           True       True         True                    False
# 27  R2  L          False       True        False                    False
# 28  R1  R           True      False         True                     True
# 29  R1  L          False      False         True                    False
# 30  R2  L          False       True         True                    False
# 31  R1  R           True      False         True                     True
# 32  L1  R          False       True        False                    False
#
#     cC_iI
# 0   False
# 1   False
# 2   False
# 3   False
# 4    True
# 5    True
# 6    True
# 7   False
# 8    True
# 9   False
# 10   True
# 11  False
# 12  False
# 13   True
# 14  False
# 15   True
# 16   True
# 17  False
# 18  False
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24  False
# 25   True
# 26   True
# 27  False
# 28  False
# 29  False
# 30   True
# 31  False
# 32  False

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05)").query("(percent_cC_iI>.45) and (percent_cC_iI<.55)").query("(S_R_loc_rep>-.15) and (S_R_loc_rep<.15)")
# Out:
#        S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 10932       0.133929      -0.053571    -0.142857  -0.205357
# 23075       0.066667      -0.133333    -0.133333   0.066667
# 29585       0.142857      -0.142857    -0.125000  -0.125000
# 29745      -0.125000      -0.125000    -0.133929   0.008929
# 52839      -0.526786      -0.098214    -0.071429   0.071429
# 69524      -0.205357       0.080357    -0.080357   0.205357
# 83393      -0.133929      -0.071429    -0.089286  -0.401786
#
#        complete_match_mismatch  percent_cC_iI
# 10932                 0.008929       0.466667
# 23075                 0.000000       0.500000
# 29585                -0.008929       0.533333
# 29745                 0.000000       0.533333
# 52839                 0.000000       0.533333
# 69524                -0.044643       0.533333
# 83393                -0.044643       0.466667

# %%
blocks[203165].to_csv('very_close_4s.csv')

# %%
blocks[203165]
# Out:
#     S1 R1  S2 R2  S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 0   L2  R  L1  R          False           True        False       True
# 1   L1  R  R2  R          False          False        False      False
# 2   R2  R  L2  L           True          False         True      False
# 3   L2  L  R2  R           True          False         True      False
# 4   R2  R  L2  R           True           True        False      False
# 5   L2  R  R2  R          False          False        False      False
# 6   R2  R  L2  R           True           True        False      False
# 7   L2  R  L1  R          False           True        False       True
# 8   L1  R  L2  R          False           True        False       True
# 9   L2  R  R2  R          False          False        False      False
# 10  R2  R  R1  L           True          False         True      False
# 11  R1  L  R2  R          False          False         True       True
# 12  R2  R  R1  R           True          False        False       True
# 13  R1  R  L1  R           True           True        False      False
# 14  L1  R  R1  R          False          False        False      False
# 15  R1  R  R2  R           True          False        False       True
# 16  R2  R  R2  L           True           True         True       True
# 17  R2  L  R2  L          False           True        False       True
# 18  R2  L  L1  L           True           True         True       True
# 19  L1  L  L1  L          False          False        False      False
# 20  L1  L  L2  R           True           True         True       True
# 21  L2  R  R2  R          False          False        False      False
# 22  R2  R  L2  L           True          False         True      False
# 23  L2  L  R1  R           True          False         True      False
# 24  R1  R  L1  L          False           True        False       True
# 25  L1  L  R1  L           True          False        False       True
# 26  R1  L  R2  R          False          False         True       True
# 27  R2  R  L2  R           True           True        False      False
# 28  L2  R  L2  L          False          False         True       True
# 29  L2  L  L1  L          False           True         True      False
# 30  L1  L  R2  R           True          False         True      False
# 31  R2  R  R2  L           True           True         True       True
# 32  R2  L  R2  L          False           True        False       True
#
#     complete_match_mismatch  cC_iI
# 0                      True  False
# 1                      True   True
# 2                     False  False
# 3                     False  False
# 4                      True   True
# 5                      True   True
# 6                      True   True
# 7                      True  False
# 8                      True  False
# 9                      True   True
# 10                    False  False
# 11                    False   True
# 12                     True  False
# 13                     True   True
# 14                     True   True
# 15                     True  False
# 16                    False   True
# 17                     True  False
# 18                    False   True
# 19                    False  False
# 20                    False   True
# 21                     True   True
# 22                    False  False
# 23                    False  False
# 24                     True  False
# 25                     True  False
# 26                    False   True
# 27                     True   True
# 28                    False   True
# 29                    False  False
# 30                    False  False
# 31                    False   True
# 32                     True  False

# %%
df.to_csv('ss4_rs2_30t.csv')

# %%
#ss6_rs2_30t = df
#ss6_rs2_30t.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05)").query("(percent_cC_iI>.45) and (percent_cC_iI<.55)").query("(S_R_loc_rep>-.05) and (S_R_loc_rep<.05)")
# Out:
#        S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 936        -0.071429      -0.071429    -0.044643   0.330357
# 2828        0.071429       0.071429     0.008929   0.133929
# 3383       -0.062500      -0.062500    -0.026786   0.401786
# 16308      -0.066667       0.000000     0.000000   0.200000
#
#        complete_match_mismatch  percent_cC_iI
# 936                  -0.017857       0.466667
# 2828                 -0.008929       0.466667
# 3383                  0.026786       0.533333
# 16308                 0.000000       0.500000

# %%
blocks[45060]
# Out:
#     S1 R1  S2 R2  S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 0   L1  R  R3  L          False          False        False      False
# 1   R3  L  R1  L          False          False         True       True
# 2   R1  L  L1  R          False          False        False      False
# 3   L1  R  L2  L          False           True        False       True
# 4   L2  L  R1  L           True          False         True      False
# 5   R1  L  R3  L          False          False         True       True
# 6   R3  L  R2  L          False          False         True       True
# 7   R2  L  L3  L          False           True         True      False
# 8   L3  L  L1  L           True           True         True       True
# 9   L1  L  R1  L           True          False         True      False
# 10  R1  L  R2  R          False           True        False       True
# 11  R2  R  L1  R           True          False         True      False
# 12  L1  R  L2  L          False           True        False       True
# 13  L2  L  R1  L           True          False         True      False
# 14  R1  L  L3  R          False          False        False      False
# 15  L3  R  L2  L          False           True        False       True
# 16  L2  L  R3  R           True           True        False      False
# 17  R3  R  L1  R           True          False         True      False
# 18  L1  R  R3  L          False          False        False      False
# 19  R3  L  L3  L          False           True         True      False
# 20  L3  L  L1  R           True          False        False       True
# 21  L1  R  L3  R          False          False         True       True
# 22  L3  R  L2  R          False          False         True       True
# 23  L2  R  R3  L          False          False        False      False
# 24  R3  L  R1  R          False           True        False       True
# 25  R1  R  R3  R           True           True         True       True
# 26  R3  R  L3  L           True           True        False      False
# 27  L3  L  R1  L           True          False         True      False
# 28  R1  L  R3  R          False           True        False       True
# 29  R3  R  R2  L           True          False        False       True
#
#     complete_match_mismatch  cC_iI
# 0                      True   True
# 1                     False   True
# 2                      True   True
# 3                      True  False
# 4                     False  False
# 5                     False   True
# 6                     False   True
# 7                     False  False
# 8                     False   True
# 9                     False  False
# 10                     True  False
# 11                    False  False
# 12                     True  False
# 13                    False  False
# 14                     True   True
# 15                     True  False
# 16                     True   True
# 17                    False  False
# 18                     True   True
# 19                    False  False
# 20                     True  False
# 21                    False   True
# 22                    False   True
# 23                     True   True
# 24                     True  False
# 25                    False   True
# 26                     True   True
# 27                    False  False
# 28                     True  False
# 29                     True  False

# %%
blocks[2036]
# Out:
#     S1 R1  S2 R2  S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 0   L3  R  L2  L          False           True        False       True
# 1   L2  L  R3  L           True          False         True      False
# 2   R3  L  R1  L          False          False         True       True
# 3   R1  L  R2  R          False           True        False       True
# 4   R2  R  L3  L           True           True        False      False
# 5   L3  L  R1  L           True          False         True      False
# 6   R1  L  R2  L          False          False         True       True
# 7   R2  L  R3  R          False           True        False       True
# 8   R3  R  L2  L           True           True        False      False
# 9   L2  L  R2  R           True           True        False      False
# 10  R2  R  R3  R           True           True         True       True
# 11  R3  R  L3  R           True          False         True      False
# 12  L3  R  L2  L          False           True        False       True
# 13  L2  L  R3  L           True          False         True      False
# 14  R3  L  R1  L          False          False         True       True
# 15  R1  L  R3  L          False          False         True       True
# 16  R3  L  L3  R          False          False        False      False
# 17  L3  R  R2  R          False           True         True      False
# 18  R2  R  R3  L           True          False        False       True
# 19  R3  L  R2  L          False          False         True       True
# 20  R2  L  L3  R          False          False        False      False
# 21  L3  R  R1  L          False          False        False      False
# 22  R1  L  R2  R          False           True        False       True
# 23  R2  R  L2  L           True           True        False      False
# 24  L2  L  R1  R           True           True        False      False
# 25  R1  R  R2  R           True           True         True       True
# 26  R2  R  R3  L           True          False        False       True
# 27  R3  L  L3  L          False           True         True      False
# 28  L3  L  R2  L           True          False         True      False
# 29  R2  L  R1  L          False          False         True       True
#
#     complete_match_mismatch  cC_iI
# 0                      True  False
# 1                     False  False
# 2                     False   True
# 3                      True  False
# 4                      True   True
# 5                     False  False
# 6                     False   True
# 7                      True  False
# 8                      True   True
# 9                      True   True
# 10                    False   True
# 11                    False  False
# 12                     True  False
# 13                    False  False
# 14                    False   True
# 15                    False   True
# 16                     True   True
# 17                    False  False
# 18                     True  False
# 19                    False   True
# 20                     True   True
# 21                     True   True
# 22                     True  False
# 23                     True   True
# 24                     True   True
# 25                    False   True
# 26                     True  False
# 27                    False  False
# 28                    False  False
# 29                    False   True

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05) ")

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05) ")
# Out:
#        S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 4          -0.200000      -0.133333    -0.200000   0.133333
# 12          0.187500       0.187500    -0.142857   0.142857
# 32          0.111111       0.111111    -0.277778   0.055556
# 103         0.066667       0.133333    -0.133333  -0.066667
# 109        -0.185520      -0.108597    -0.167421  -0.244344
# ...              ...            ...          ...        ...
# 19880      -0.033493      -0.124402    -0.282297  -0.191388
# 19913       0.083333       0.083333    -0.166667   0.166667
# 19922       0.055556       0.055556    -0.305556   0.194444
# 19926       0.000000       0.000000    -0.055556   0.055556
# 19937       0.344498       0.291866    -0.320574   0.047847
#
#        complete_match_mismatch  percent_cC_iI
# 4                     0.000000       0.500000
# 12                    0.017857       0.533333
# 32                   -0.027778       0.600000
# 103                   0.000000       0.500000
# 109                  -0.027149       0.566667
# ...                        ...            ...
# 19880                -0.019139       0.633333
# 19913                 0.000000       0.400000
# 19922                 0.027778       0.600000
# 19926                 0.000000       0.400000
# 19937                 0.019139       0.366667
#
# [704 rows x 6 columns]

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05)").query('percent_cC_iI==.5')
# Out:
#        S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 4          -0.200000      -0.133333    -0.200000   0.133333
# 103         0.066667       0.133333    -0.133333  -0.066667
# 418        -0.066667      -0.133333    -0.066667   0.000000
# 719         0.400000       0.466667    -0.200000   0.133333
# 745         0.133333       0.200000    -0.266667  -0.333333
# ...              ...            ...          ...        ...
# 18636       0.000000      -0.066667    -0.466667   0.000000
# 18801      -0.266667      -0.200000    -0.200000  -0.133333
# 19026       0.066667       0.000000    -0.533333   0.066667
# 19352       0.000000       0.066667    -0.266667  -0.066667
# 19672       0.266667       0.200000    -0.266667   0.066667
#
#        complete_match_mismatch  percent_cC_iI
# 4                          0.0            0.5
# 103                        0.0            0.5
# 418                        0.0            0.5
# 719                        0.0            0.5
# 745                        0.0            0.5
# ...                        ...            ...
# 18636                      0.0            0.5
# 18801                      0.0            0.5
# 19026                      0.0            0.5
# 19352                      0.0            0.5
# 19672                      0.0            0.5
#
# [63 rows x 6 columns]

# %%
df.query("(complete_match_mismatch>-.05) and (complete_match_mismatch<.05)").query("(percent_cC_iI>.45) and (percent_cC_iI<.55)").query("(S_R_loc_rep>-.05) and (S_R_loc_rep<.05)")
# Out:
#        S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 936        -0.071429      -0.071429    -0.044643   0.330357
# 2828        0.071429       0.071429     0.008929   0.133929
# 3383       -0.062500      -0.062500    -0.026786   0.401786
# 16308      -0.066667       0.000000     0.000000   0.200000
#
#        complete_match_mismatch  percent_cC_iI
# 936                  -0.017857       0.466667
# 2828                 -0.008929       0.466667
# 3383                  0.026786       0.533333
# 16308                 0.000000       0.500000

# %%
blocks[16308]
# Out:
#     S1 R1  S2 R2  S1_R1_corresp  S2_R2_corresp  S_R_loc_rep  S_loc_rep  \
# 0   L3  R  R2  L          False          False        False      False
# 1   R2  L  L3  L          False           True         True      False
# 2   L3  L  R3  L           True          False         True      False
# 3   R3  L  L1  R          False          False        False      False
# 4   L1  R  L2  R          False          False         True       True
# 5   L2  R  L3  L          False           True        False       True
# 6   L3  L  L1  L           True           True         True       True
# 7   L1  L  R3  L           True          False         True      False
# 8   R3  L  L2  L          False           True         True      False
# 9   L2  L  R2  L           True          False         True      False
# 10  R2  L  L2  R          False          False        False      False
# 11  L2  R  L3  L          False           True        False       True
# 12  L3  L  L2  L           True           True         True       True
# 13  L2  L  L3  L           True           True         True       True
# 14  L3  L  L2  L           True           True         True       True
# 15  L2  L  L3  R           True          False        False       True
# 16  L3  R  L1  R          False          False         True       True
# 17  L1  R  R2  R          False           True         True      False
# 18  R2  R  L1  L           True           True        False      False
# 19  L1  L  L3  R           True          False        False       True
# 20  L3  R  R2  L          False          False        False      False
# 21  R2  L  L3  R          False          False        False      False
# 22  L3  R  L2  L          False           True        False       True
# 23  L2  L  L1  R           True          False        False       True
# 24  L1  R  L2  L          False           True        False       True
# 25  L2  L  R2  R           True           True        False      False
# 26  R2  R  R1  L           True          False        False       True
# 27  R1  L  R3  R          False           True        False       True
# 28  R3  R  L2  L           True           True        False      False
# 29  L2  L  R3  R           True           True        False      False
#
#     complete_match_mismatch  cC_iI
# 0                      True   True
# 1                     False  False
# 2                     False  False
# 3                      True   True
# 4                     False   True
# 5                      True  False
# 6                     False   True
# 7                     False  False
# 8                     False  False
# 9                     False  False
# 10                     True   True
# 11                     True  False
# 12                    False   True
# 13                    False   True
# 14                    False   True
# 15                     True  False
# 16                    False   True
# 17                    False  False
# 18                     True   True
# 19                     True  False
# 20                     True   True
# 21                     True   True
# 22                     True  False
# 23                     True  False
# 24                     True  False
# 25                     True   True
# 26                     True  False
# 27                     True  False
# 28                     True   True
# 29                     True   True

# %%
#| hide
import nbdev; nbdev.nbdev_export()
